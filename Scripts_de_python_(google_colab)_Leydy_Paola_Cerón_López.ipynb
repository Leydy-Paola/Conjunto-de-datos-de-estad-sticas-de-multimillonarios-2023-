# %% [markdown]
# # Proyecto final

# %% [markdown]
# ##Fase 1: Limpieza de datos

# %%
#Cargar el archivo CSV desde tu computadora:
from google.colab import files

# Selecciona el archivo CSV desde tu computadora
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f6811f9-42c2-406b-b918-b34374d162e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f6811f9-42c2-406b-b918-b34374d162e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Importar libreria requerida
import pandas as pd
import io

# Lee el archivo CSV desde el objeto uploaded
df = pd.read_csv(io.BytesIO(uploaded['Billionaires Statistics Dataset.csv']))

# %%
#visualizar la tabla con su información en general
df
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
# Verifica valores nulos en el DataFrame
print(df.isnull().sum())
# Out:
# rank                                             0
# finalWorth                                       0
# category                                         0
# personName                                       0
# age                                             65
# country                                         38
# city                                            72
# source                                           0
# industries                                       0
# countryOfCitizenship                             0
# organization                                  2315
# selfMade                                         0
# status                                           0
# gender                                           0
# birthDate                                       76
# lastName                                         0
# firstName                                        3
# title                                         2301
# ...

# %%
# Elimina filas con valores nulos y actualiza el DataFrame
df = df.dropna()

#Una vez eliminadas pasamos a visualizar si tenemos vacios o datos nulos
print(df.isnull().sum())
df
# Out:
# rank                                          0
# finalWorth                                    0
# category                                      0
# personName                                    0
# age                                           0
# country                                       0
# city                                          0
# source                                        0
# industries                                    0
# countryOfCitizenship                          0
# organization                                  0
# selfMade                                      0
# status                                        0
# gender                                        0
# birthDate                                     0
# lastName                                      0
# firstName                                     0
# title                                         0
# date                                          0
# state                                         0
# ...

# %%
#Verificamos datos nulos por columnas
print(df['finalWorth'].isnull().sum())
# Out:
# 0

# %%
# Observar detalladamente los diferentes valores del datasets, permitiendonos detectar anomalías a primera vista.
print(df.describe)
# Out:
# <bound method NDFrame.describe of       rank  finalWorth               category      personName   age  \
# 1        2      180000             Automotive       Elon Musk  51.0
# 2        3      114000             Technology      Jeff Bezos  59.0
# 3        4      107000             Technology   Larry Ellison  78.0
# 4        5      106000  Finance & Investments  Warren Buffett  92.0
# 5        6      104000             Technology      Bill Gates  67.0
# ...    ...         ...                    ...             ...   ...
# 2519  2405        1100                 Sports     Tiger Woods  47.0
# 2566  2540        1000       Fashion & Retail  William Fisher  66.0
# 2581  2540        1000                 Sports    LeBron James  38.0
# 2602  2540        1000             Technology   Apoorva Mehta  36.0
# 2608  2540        1000  Media & Entertainment     Tyler Perry  53.0
#
#             country            city                    source  \
# ...

# %%
# Obtén los nombres de todas las columnas
nombres_columnas = df.columns

# Convertir los nombres de las columnas a una lista para mayor facilidad
lista_nombres_columnas = list(nombres_columnas)

# Imprimir los nombres de las columnas
print(lista_nombres_columnas)
# Out:
# ['rank', 'finalWorth', 'category', 'personName', 'age', 'country', 'city', 'source', 'industries', 'countryOfCitizenship', 'organization', 'selfMade', 'status', 'gender', 'birthDate', 'lastName', 'firstName', 'title', 'date', 'state', 'residenceStateRegion', 'birthYear', 'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country', 'gdp_country', 'gross_tertiary_education_enrollment', 'gross_primary_education_enrollment_country', 'life_expectancy_country', 'tax_revenue_country_country', 'total_tax_rate_country', 'population_country', 'latitude_country', 'longitude_country']

# %% [markdown]
# ##Eliminar las columnas Irrelevantes para nuestro dataset según objetivos de proyecto

# %% [markdown]
# **NOTA:** Una vez que hemos ya eliminado por primera vez de nuestro dataset las columnas y volvemos a ejecutar el código drop, nos dará un error debido a que esas columnas ya fueron eliminadas, y por lo tanto, ya no exite en nuestra base de datos

# %%
# Lista de nombres de las columnas a eliminar
columnas_a_eliminar = ['selfMade', 'lastName', 'firstName', 'cpi_country', 'cpi_change_country', 'gdp_country', 'gross_tertiary_education_enrollment', 'gross_primary_education_enrollment_country', 'life_expectancy_country', 'tax_revenue_country_country', 'total_tax_rate_country', 'population_country', 'latitude_country', 'longitude_country']

# Elimina las columnas especificadas
df = df.drop(columns=columnas_a_eliminar)

# %%
# Imprimir los nombres de las columnas para verificar nuevamente que ya no se encuentren las columnas eliminadas
print(lista_nombres_columnas)
# Out:
# ['rank', 'finalWorth', 'category', 'personName', 'age', 'country', 'city', 'source', 'industries', 'countryOfCitizenship', 'organization', 'selfMade', 'status', 'gender', 'birthDate', 'lastName', 'firstName', 'title', 'date', 'state', 'residenceStateRegion', 'birthYear', 'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country', 'gdp_country', 'gross_tertiary_education_enrollment', 'gross_primary_education_enrollment_country', 'life_expectancy_country', 'tax_revenue_country_country', 'total_tax_rate_country', 'population_country', 'latitude_country', 'longitude_country']

# %%
df
# Out:
#       rank  finalWorth               category      personName   age  \
# 1        2      180000             Automotive       Elon Musk  51.0
# 2        3      114000             Technology      Jeff Bezos  59.0
# 3        4      107000             Technology   Larry Ellison  78.0
# 4        5      106000  Finance & Investments  Warren Buffett  92.0
# 5        6      104000             Technology      Bill Gates  67.0
# ...    ...         ...                    ...             ...   ...
# 2519  2405        1100                 Sports     Tiger Woods  47.0
# 2566  2540        1000       Fashion & Retail  William Fisher  66.0
# 2581  2540        1000                 Sports    LeBron James  38.0
# 2602  2540        1000             Technology   Apoorva Mehta  36.0
# 2608  2540        1000  Media & Entertainment     Tyler Perry  53.0
#
#             country            city                    source  \
# 1     United States          Austin             Tesla, SpaceX
# ...

# %% [markdown]
# ##Asegurandose que las edades sean números enteros (sin decimales)

# %% [markdown]
# Pero antes vamos a crear una manera más simplificada de visualizar los datos de nuestro dataset con df.head

# %%
#Este código imprimirá las primeras 5 filas del DataFrame df.
df.head()
# Out:
#    rank  finalWorth               category      personName   age  \
# 1     2      180000             Automotive       Elon Musk  51.0
# 2     3      114000             Technology      Jeff Bezos  59.0
# 3     4      107000             Technology   Larry Ellison  78.0
# 4     5      106000  Finance & Investments  Warren Buffett  92.0
# 5     6      104000             Technology      Bill Gates  67.0
#
#          country    city              source             industries  \
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
# 5  United States  Medina           Microsoft             Technology
#
#   countryOfCitizenship  ... status gender        birthDate  \
# 1        United States  ...      D      M   6/28/1971 0:00
# ...

# %% [markdown]
# Como pudimos visualizar los datos de la columna **"age"** están en decimales, por lo que realizaremos el cambio a números enteros, como lo mostraremos a continuación;

# %%
# Convierte la columna 'age' a tipo de dato entero
df['age'] = df['age'].astype(int)
df.head()
# Out:
#    rank  finalWorth               category      personName  age  \
# 1     2      180000             Automotive       Elon Musk   51
# 2     3      114000             Technology      Jeff Bezos   59
# 3     4      107000             Technology   Larry Ellison   78
# 4     5      106000  Finance & Investments  Warren Buffett   92
# 5     6      104000             Technology      Bill Gates   67
#
#          country    city              source             industries  \
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
# 5  United States  Medina           Microsoft             Technology
#
#   countryOfCitizenship  ... status gender        birthDate  \
# 1        United States  ...      D      M   6/28/1971 0:00
# ...

# %% [markdown]
# Eliminamos columnas filtradas con datos nulos y que no pertenecen a nuestro conjunto de datos requeridos

# %%
# Lista de nombres de las columnas que deseas eliminar
columnas_a_eliminar2 = ['date']

# Elimina las columnas especificadas del DataFrame
df = df.drop(columns=columnas_a_eliminar2)

# %%
# Lista de nombres de las columnas que deseas eliminar
columnas_a_eliminar3 = ['birthYear','birthMonth','birthDay']

# Elimina las columnas especificadas del DataFrame
df = df.drop(columns=columnas_a_eliminar3)

# %% [markdown]
# ##Cambiando formato a los datos

# %% [markdown]
# Ahora pasamos a eliminar la parte de la hora (0:00) de la columna 'birthDate', para esto usamos el método pd.to_datetime() para convertir la columna a objetos de tipo datetime y luego usar dt.date para quedarnos solo con la parte de la fecha y eliminar la parte de la hora

# %%
# Convertimos la columna 'birthDate	' a formato datetime y luego a solo fecha y visualizamos nuevamente
df['birthDate'] = pd.to_datetime(df['birthDate']).dt.date
df.head()
# Out:
#    rank  finalWorth               category      personName  age  \
# 1     2      180000             Automotive       Elon Musk   51
# 2     3      114000             Technology      Jeff Bezos   59
# 3     4      107000             Technology   Larry Ellison   78
# 4     5      106000  Finance & Investments  Warren Buffett   92
# 5     6      104000             Technology      Bill Gates   67
#
#          country    city              source             industries  \
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
# 5  United States  Medina           Microsoft             Technology
#
#   countryOfCitizenship                     organization status gender  \
# 1        United States                            Tesla      D      M
# ...

# %%
#Visualizamos los tipos de datos de nuestra dataset
print(df.dtypes)
# Out:
# rank                     int64
# finalWorth               int64
# category                object
# personName              object
# age                      int64
# country                 object
# city                    object
# source                  object
# industries              object
# countryOfCitizenship    object
# organization            object
# status                  object
# gender                  object
# birthDate               object
# title                   object
# state                   object
# residenceStateRegion    object
# dtype: object

# %% [markdown]
# Es preferible manejar un solo tipo de datos, sin embargo el cambio de algunos datos en sus formatos, se irán ajustando en el momento de visualizarlo con PowerBi

# %%
# Convierte la columna 'birthDate' a objetos de fecha y hora
df['birthDate'] = pd.to_datetime(df['birthDate'])

# Verifica que la conversión se haya realizado correctamente
print(df['birthDate'])
# Out:
# 1      1971-06-28
# 2      1964-01-12
# 3      1944-08-17
# 4      1930-08-30
# 5      1955-10-28
#           ...
# 2519   1975-12-30
# 2566   1957-04-01
# 2581   1984-12-30
# 2602   1986-07-19
# 2608   1969-09-14
# Name: birthDate, Length: 238, dtype: datetime64[ns]

# %% [markdown]
# ##Ordenando en orden ascendente

# %%
# Ordena el DataFrame por la columna 'rank' en orden ascendente
df = df.sort_values(by='rank', ascending=True)

# Muestra las primeras filas del DataFrame ordenado
df.head()
# Out:
#    rank  finalWorth               category      personName  age  \
# 1     2      180000             Automotive       Elon Musk   51
# 2     3      114000             Technology      Jeff Bezos   59
# 3     4      107000             Technology   Larry Ellison   78
# 4     5      106000  Finance & Investments  Warren Buffett   92
# 5     6      104000             Technology      Bill Gates   67
#
#          country    city              source             industries  \
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
# 5  United States  Medina           Microsoft             Technology
#
#   countryOfCitizenship                     organization status gender  \
# 1        United States                            Tesla      D      M
# ...

# %% [markdown]
# ##Convertir el número en tu conjunto de datos a dólares con dos ceros demás antes de la coma

# %%
# Multiplica el número por 100 para agregar dos ceros antes de la coma
df['finalWorth'] = df['finalWorth'] * 100

# Convierte el número a dólares y formatea con dos ceros antes de la coma
df['finalWorth'] = df['finalWorth'].apply(lambda x: '${:,.2f}'.format(x))

# Imprime el DataFrame para verificar los cambios
print(df)
# Out:
#       rank      finalWorth               category      personName  age  \
# 1        2  $18,000,000.00             Automotive       Elon Musk   51
# 2        3  $11,400,000.00             Technology      Jeff Bezos   59
# 3        4  $10,700,000.00             Technology   Larry Ellison   78
# 4        5  $10,600,000.00  Finance & Investments  Warren Buffett   92
# 5        6  $10,400,000.00             Technology      Bill Gates   67
# ...    ...             ...                    ...             ...  ...
# 2491  2405     $110,000.00       Fashion & Retail     Kevin Plank   50
# 2581  2540     $100,000.00                 Sports    LeBron James   38
# 2602  2540     $100,000.00             Technology   Apoorva Mehta   36
# 2566  2540     $100,000.00       Fashion & Retail  William Fisher   66
# 2608  2540     $100,000.00  Media & Entertainment     Tyler Perry   53
#
#             country                  city                    source  \
# ...

# %%
#Visualizamos de manera más clara el cambio obtenido
df.head()
# Out:
#    rank      finalWorth               category      personName  age  \
# 1     2  $18,000,000.00             Automotive       Elon Musk   51
# 2     3  $11,400,000.00             Technology      Jeff Bezos   59
# 3     4  $10,700,000.00             Technology   Larry Ellison   78
# 4     5  $10,600,000.00  Finance & Investments  Warren Buffett   92
# 5     6  $10,400,000.00             Technology      Bill Gates   67
#
#          country    city              source             industries  \
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
# 5  United States  Medina           Microsoft             Technology
#
#   countryOfCitizenship                     organization status gender  \
# 1        United States                            Tesla      D      M
# ...

# %% [markdown]
# ##Cambiando nombres de columnas

# %%
# Definimos un diccionario que mapee los nombres antiguos a los nuevos nombres
nuevos_nombres = {
    "residenceStateRegion": "Región de residencia",
    "gender": "Género",
    "countryOfCitizenship": "País de ciudadanía ",
    "personName": "Nombre",
    "finalWorth": "Patrimonio neto",
    "source": "Fuente de riqueza",
}

# Cambiamos los nombres de las columnas usando el método rename()
df.rename(columns=nuevos_nombres, inplace=True)

# Mostramos las primeras filas para verificar los cambios
df.head()
# Out:
#    rank Patrimonio neto               category          Nombre  age  \
# 1     2  $18,000,000.00             Automotive       Elon Musk   51
# 2     3  $11,400,000.00             Technology      Jeff Bezos   59
# 3     4  $10,700,000.00             Technology   Larry Ellison   78
# 4     5  $10,600,000.00  Finance & Investments  Warren Buffett   92
# 5     6  $10,400,000.00             Technology      Bill Gates   67
#
#          country    city   Fuente de riqueza             industries  \
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
# 5  United States  Medina           Microsoft             Technology
#
#   País de ciudadanía                      organization status Género  \
# 1       United States                            Tesla      D      M
# ...

# %%
#visualizamos finalmente nuestra tabla completa con los datos limpios y preparados
df
# Out:
#       rank Patrimonio neto               category          Nombre  age  \
# 1        2  $18,000,000.00             Automotive       Elon Musk   51
# 2        3  $11,400,000.00             Technology      Jeff Bezos   59
# 3        4  $10,700,000.00             Technology   Larry Ellison   78
# 4        5  $10,600,000.00  Finance & Investments  Warren Buffett   92
# 5        6  $10,400,000.00             Technology      Bill Gates   67
# ...    ...             ...                    ...             ...  ...
# 2491  2405     $110,000.00       Fashion & Retail     Kevin Plank   50
# 2581  2540     $100,000.00                 Sports    LeBron James   38
# 2602  2540     $100,000.00             Technology   Apoorva Mehta   36
# 2566  2540     $100,000.00       Fashion & Retail  William Fisher   66
# 2608  2540     $100,000.00  Media & Entertainment     Tyler Perry   53
#
#             country                  city         Fuente de riqueza  \
# ...

# %% [markdown]
# ##Integración archivo CSV y PowerBi

# %% [markdown]
# Para integrar los datos limpios y preparados en Google Colab con Power BI Desktop, ejecutamos el siguiente comando, y luego descargamos el archivo csv en nuestro pc, para luego hacer la integración requerida

# %%
# Guarda el DataFrame en un archivo CSV
df.to_csv('datos_limpios.csv', index=False)

# %% [markdown]
# Una vez descargado en nuestro pc, finalmente hemos terminado la parte de preparación y limpieza de nuestros datos, y pasamos a integrarlo con PowerBi Desktop, y visualizar el informe con los graficos adecuados para su fácil interpretación.

# %% [markdown]
# ##Perfilamiento de la calidad de datos

# %% [markdown]
# Esta biblioteca proporciona una manera fácil de realizar análisis exploratorio de datos (EDA) en conjuntos de datos de Pandas. Con ella, puedes generar un informe detallado sobre la estructura del conjunto de datos, estadísticas descriptivas, visualizaciones y más, con solo una línea de código. Es una herramienta útil para comprender rápidamente los datos que estás tratando en Python.

# %%
# Esta biblioteca proporciona un informe de análisis exploratorio de datos (EDA) con una sola línea de código
# !pip install pandas_profiling==3.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 6.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.0/354.0 kB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 20.1 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=24e7da2a79d1db16d41be3daecd5dccce180ad8a2fd1d813dc0b12538101cc51
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %% [markdown]
# Una vez que tenemos el ambiente listo, se puede importar la librería y utilizar el método pandas_profiling.ProfileReport(dataframe)

# %%
# !pip install pandas_profiling --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.3/357.3 kB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 10.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.1
#     Uninstalling visions-0.7.1:
#       Successfully uninstalled visions-0.7.1
#   Attempting uninstall: pandas_profiling
#     Found existing installation: pandas-profiling 3.0.0
#     Uninstalling pandas-profiling-3.0.0:
#       Successfully uninstalled pandas-profiling-3.0.0
# ...

# %% [markdown]
# El comando import pandas_profiling se utiliza en Python para importar la biblioteca pandas_profiling. Después de ejecutar este comando, puedes utilizar las funciones y clases proporcionadas por pandas_profiling en tu código.

# %%
# Importando la biblioteca pandas_profiling
# Esta biblioteca proporciona herramientas para el análisis exploratorio de datos, permitiendo generar informes detallados de un DataFrame
import pandas_profiling
# Out:
# <ipython-input-28-df4dac89d685>:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %% [markdown]
# El siguiente código utiliza pandas_profiling para realizar un análisis exploratorio de datos en el DataFrame df. este nos permitira, guardar el informe generado como un archivo HTML y, opcionalmente, poder mostrar el informe directamente dentro del notebook

# %%
import pandas_profiling

# Generar el informe
automobileProfile = pandas_profiling.ProfileReport(df)

# Guardar el informe como un archivo HTML
automobileProfile.to_file(output_file="Billionaires Statistics Dataset.html")

# Si deseas visualizar el informe dentro del notebook puedes usar la siguiente línea:
# automobileProfile.to_notebook_iframe()
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Utilizando el comando to_file se puede exportar el reporte a un archivo HTML que se guardará en la carpeta Sample Data de Google Colab, este archivo se puede descargar para su posterior uso

# %%
automobileProfile.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-10-05 15:34:32.500151&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
